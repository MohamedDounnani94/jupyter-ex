# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
churn_miss = pd.read_csv('churn_miss')

# %%
churn_miss.head()
# Out:
#    gender   age    paymethod  lasttrans  label
# 0  female  54.0     bancomat      146.0    NaN
# 1    male  52.0  credit card      132.0  loyal
# 2    male  25.0  credit card       89.0  loyal
# 3    male  52.0  credit card       78.0  loyal
# 4    male  47.0         cash      163.0  loyal

# %%
churn_miss.describe()
# Out:
#               age   lasttrans
# count  981.000000  993.000000
# mean    45.707441  110.895267
# std     18.776642   44.910070
# min     17.000000    1.000000
# 25%     30.000000   77.000000
# 50%     44.000000  110.000000
# 75%     58.000000  144.000000
# max     91.000000  223.000000

# %%
sb.countplot(x = 'gender', data = churn_miss)

# %%
sb.barplot (x = 'gender', y = 'lasttrans', data = churn_miss, palette = 'rainbow')

# %%
sb.stripplot(x = 'label', y = 'age', data = churn_miss, hue = 'gender', jitter = True)

# %%
sb.lmplot(x = 'lasttrans', y = 'age', data = churn_miss, hue = 'gender')

# %% [markdown]
# sb.lmplot(x = 'lasttrans', y = 'age', data = churn_miss, col = 'gender')

# %%
sb.lmplot(x = 'lasttrans', y = 'age', data = churn_miss, col = 'gender')

# %%
sb.heatmap(churn_miss.isnull(), yticklabels = False)
